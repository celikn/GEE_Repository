# %% [markdown]
# <a href="https://colab.research.google.com/github/celikn/GEE_Repository/blob/main/ChangeDetectionCNN_20220228.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d soumikrakshit/onera-satellite-change-detection-dataset
# Out:
# Downloading onera-satellite-change-detection-dataset.zip to /content
#  98% 495M/504M [00:04<00:00, 99.1MB/s]
# 100% 504M/504M [00:04<00:00, 106MB/s]

# %%
# !unzip onera-satellite-change-detection-dataset.zip
# Out:
# Archive:  onera-satellite-change-detection-dataset.zip
#   inflating: images/Onera Satellite Change Detection dataset - Images/README.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/abudhabi.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1/S2A_OPER_MSI_L1C_TL_MTI__20160120T104345_A003020_T39QZG_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2/T40QBM_20180328T065919_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/abudhabi/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/aguasclaras.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2/T22LHH_20171015T133221_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/aguasclaras/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/all.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/beihai.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1/T49QCD_20161209T031122_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2/T49QCD_20180309T030539_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/beihai/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/beirut.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20160929T004310_A000833_T36SYC_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2/T36SYC_20171003T081739_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/beirut/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/bercy.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1/S2A_OPER_MSI_L1C_TL_MPS__20161130T130757_A007527_T31UDQ_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2/T31UDQ_20170829T105019_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/bercy/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/bordeaux.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160504T163055_A004524_T30TXQ_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2/T30TXQ_20171026T110131_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/bordeaux/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/brasilia.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1/S2A_OPER_MSI_L1C_TL_EPA__20161227T091305_A001222_T22LHH_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2/T22LHH_20171017T132219_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/brasilia/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/chongqing.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1/T48RXT_20170414T032541_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/chongqing/imgs_1_rect/B09.tif
# ...
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160315T201048_A003809_T31UDP_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2/T31UDQ_20170829T105019_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/saclay_w/saclay_w.geojson
#   inflating: images/Onera Satellite Change Detection dataset - Images/test.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/train.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/dates.txt
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1/S2A_OPER_MSI_L1C_TL_SGS__20160730T161632_A005768_T30SYJ_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_1_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2/T30SYJ_20171107T105229_B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B01.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B02.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B03.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B04.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B05.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B06.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B07.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B08.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B09.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B10.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B11.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B12.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/imgs_2_rect/B8A.tif
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/pair/img1.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/pair/img2.png
#   inflating: images/Onera Satellite Change Detection dataset - Images/valencia/valencia.geojson
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/README.txt
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/abudhabi/cm/abudhabi-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/abudhabi/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/aguasclaras/cm/aguasclaras-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/aguasclaras/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/beihai/cm/beihai-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/beihai/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/beirut/cm/beirut-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/beirut/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/bercy/cm/bercy-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/bercy/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/bordeaux/cm/bordeaux-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/bordeaux/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/cupertino/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/cupertino/cm/cupertino-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/hongkong/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/hongkong/cm/hongkong-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/mumbai/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/mumbai/cm/mumbai-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/nantes/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/nantes/cm/nantes-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/paris/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/paris/cm/paris-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/pisa/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/pisa/cm/pisa-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/rennes/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/rennes/cm/rennes-cm.tif
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/saclay_e/cm/cm.png
#   inflating: train_labels/Onera Satellite Change Detection dataset - Train Labels/saclay_e/cm/saclay_e-cm.tif

# %%
###Source: https://www.kaggle.com/soumikrakshit/onera-satellite-change-detection-dataset/code

# %%
# !pip install segmentation-models-pytorch -q
# Out:
#      |████████████████████████████████| 88 kB 3.8 MB/s
#      |████████████████████████████████| 58 kB 4.3 MB/s
#      |████████████████████████████████| 376 kB 50.7 MB/s
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done

# %%
# All the module imports in this section

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import torch
import torch.nn as nn
import torch.utils as utils
import torch.nn.init as init
import torch.utils.data as data
import torchvision.utils as v_utils
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.autograd import Variable
import numpy as np
from random import shuffle
import scipy.misc
from PIL import Image
import segmentation_models_pytorch as smp
from segmentation_models_pytorch.encoders import get_preprocessing_fn
import cv2
import os
import glob

# %%
#list of 14 cities for which images are available in the dataset

cities = ['paris',
 'rennes',
 'bercy',
 'abudhabi',
 'hongkong',
 'aguasclaras',
 'saclay_e',
 'beirut',
 'mumbai',
 'pisa',
 'beihai',
 'bordeaux',
 'cupertino',
 'nantes']

# %%
len(cities) # checking the lenght of the list
# Out:
# 14

# %%
# specifying input path to read images
input_path = "/content/images/Onera Satellite Change Detection dataset - Images"

img1 = []   # creating list of imagery paths for first set of images 
img2 = []   # creating list of imagery paths for second set of images
label = []  # creating list of change mask paths for the images

for city in cities:
    img1.append(input_path +"/"+ city + "/pair/" + "img1.png")
    img2.append(input_path +"/"+ city + "/pair/" + "img2.png")
    label.append(f"/content/train_labels/Onera Satellite Change Detection dataset - Train Labels/{city}/cm/cm.png")

# %%
# read a random sample - two set of images and the associated change mask

from PIL import Image
import matplotlib.pyplot as plt

sample = np.random.randint(0,13) # generate a random number    

im1 = Image.open(img1[sample])
im2 = Image.open(img2[sample])
lab = Image.open(label[sample]).convert('LA')
print(np.array(lab).shape)
fig,ax = plt.subplots(1,3,figsize=(10,10))
ax[0].imshow(im1)
ax[1].imshow(im2)
ax[2].imshow(lab)
# Out:
# (639, 688, 2)

# %%
# Below code to divide the whole images into patches of 64X64 

path1 = []
path2 = []
target = []
start_row = []
end_row = []
start_col = []
end_col = []

for im1,im2,lab in zip(img1,img2,label):
    for row in [0,64,128,192,256,320,384,448]:
        for col in [0,64,128,192,256,320,384,448]:
            row_start = row
            row_end = row + 64
            col_start = col
            col_end = col + 64
            
            path1.append(im1)
            path2.append(im2)
            target.append(lab)
            
            start_row.append(row_start)
            end_row.append(row_end)
            
            start_col.append(col_start)
            end_col.append(col_end)
            
df = pd.DataFrame({"path1":path1,"path2":path2,"target":target,"start_row":start_row,"end_row":end_row,"start_col":start_col,"end_col":end_col})
df
# Out:
#                                                  path1  ... end_col
# 0    /content/images/Onera Satellite Change Detecti...  ...      64
# 1    /content/images/Onera Satellite Change Detecti...  ...     128
# 2    /content/images/Onera Satellite Change Detecti...  ...     192
# 3    /content/images/Onera Satellite Change Detecti...  ...     256
# 4    /content/images/Onera Satellite Change Detecti...  ...     320
# ..                                                 ...  ...     ...
# 891  /content/images/Onera Satellite Change Detecti...  ...     256
# 892  /content/images/Onera Satellite Change Detecti...  ...     320
# 893  /content/images/Onera Satellite Change Detecti...  ...     384
# 894  /content/images/Onera Satellite Change Detecti...  ...     448
# 895  /content/images/Onera Satellite Change Detecti...  ...     512
#
# [896 rows x 7 columns]

# %%
#Python dataset class to be used for generating images and labels for training the model

class ChangeDataset():
    def __init__(self,df):
        self.df = df
        
    def __len__(self):
        return (len(self.df))
    
    def __getitem__(self,item):
        im1 = Image.open(self.df.loc[item,"path1"])
        im1 = np.array(im1.resize((512,512))) / 255 # resizing the image to 512X512
        im2 = Image.open(self.df.loc[item,"path2"])
        im2 = np.array(im2.resize((512,512))) / 255 # resizing the image to 512X512
        target = Image.open(self.df.loc[item,"target"]).convert("RGB")
        target = np.array(target.resize((512,512))) # resizing the mask to 512X512
        target = (np.mean(target,axis=-1) > 0.5).astype(np.uint8)
        start_row = self.df.loc[item,"start_row"]
        end_row = self.df.loc[item,"end_row"]
        start_col = self.df.loc[item,"start_col"]
        end_col = self.df.loc[item,"end_col"]
        
        # read a 64X64 patch from the base image1
        im1 = torch.tensor(im1[start_row:end_row,start_col:end_col,:].transpose(2,1,0),dtype=torch.float)
          # read a 64X64 patch from the base image2
        im2 = torch.tensor(im2[start_row:end_row,start_col:end_col,:].transpose(2,1,0),dtype=torch.float)
          # read a 64X64 patch from the base change mask
        target = torch.tensor(target[start_row:end_row,start_col:end_col],dtype=torch.long)
        
        return (im1,im2,target)

# %%
train_ds = ChangeDataset(df[:700])  # train dataset
val_ds = ChangeDataset(df[700:].reset_index(drop=True)) # validation dataset

sample = np.random.randint(0,100) # generate a random number

im1,im2,target = train_ds[sample] # read a random sample 
im1.shape,im2.shape,target.shape  # check shape
# Out:
# (torch.Size([3, 64, 64]), torch.Size([3, 64, 64]), torch.Size([64, 64]))

# %%
plt.imshow(target.numpy())  # plot the change mask

# %%
# plot the image1, image2 and the change mask

fig,ax = plt.subplots(1,3,figsize=(10,10))
ax[0].imshow(im1.numpy().transpose(1,2,0))
ax[1].imshow(im2.numpy().transpose(1,2,0))
ax[2].imshow(target.numpy())

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds,batch_size=256, shuffle=True)  # train dataset to train dataloader
val_dl = DataLoader(val_ds,batch_size=256, shuffle=False)  # valid dataset to valid dataloader

# %%
model = smp.Unet('resnet34', encoder_depth=3,decoder_channels=(64, 64, 16)) # build a base model based on Unet architecture with a resnet34 encoder

# %%
# ChangeNet model

class ChangeNet(nn.Module):
    def __init__(self,model):
        super().__init__()
        self.encoder = model.encoder  #model encoder
        self.decoder = model.decoder  #model decoder
        self.head = model.segmentation_head  #segmentation head for generation of change mask
        
    def forward(self,x1,x2):
        enc1 = self.encoder(x1)  # get latent features of image1
        enc2 = self.encoder(x2)  # get latent features of image2
        encoder_out = []
        for i in range(len(enc1)):
            encoder_out.append(torch.add(enc1[i],enc2[i])) # Add the latent features and append them to a list
        decoder_out = self.decoder(*encoder_out) # Pass the latent features through a decoder
        out = self.head(decoder_out) # Pass the decoder output through the segmentation head to generate change mask
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else'cpu')  #Training on gpu if available

# %%
change_model = ChangeNet(model).to(device) #migrating model to device

# %%
from tqdm.notebook import tqdm

criterion = torch.nn.BCEWithLogitsLoss().to(device)   #loss function is BCE loss since it is binary classification
optimizer = torch.optim.Adam(change_model.parameters(), lr=0.0001)

for epoch in tqdm(range(5)):  # Number of epochs = 5
    
    epoch_loss = []
    # Iterate over data.
        
    change_model.train() # setting model state to train
    for x1,x2,target in tqdm(train_dl,total=len(train_dl)):
        x1 = x1.to(device)  #migrating inputs to device
        x2 = x2.to(device)  #migrating inputs to device
        target = target.to(device)  #migrating inputs to device
                
        # zero the parameter gradients
        optimizer.zero_grad()   #resetting the optimizer

        # forward
        outputs = change_model(x1,x2)  # generating model predictions
        loss = criterion(outputs.squeeze(), target.float()) # evaluating loss

        # backward + optimize only if in training phase
        
        loss.backward()  # calculating gradients
        optimizer.step()  # using optimizer to recalculate parameters
        epoch_loss.append(loss.item())
    
    print(f"Epoch {epoch}, Loss:",np.array(epoch_loss).mean())
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0, Loss: 0.8078314264615377
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.7702416777610779
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2, Loss: 0.7367697755495707
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3, Loss: 0.7066969275474548
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4, Loss: 0.6786607503890991

# %%
len(val_ds)
# Out:
# 196

# %%
change_model.eval()  #setting model to eval for generating predictions

s = 190 # sample - random

with torch.no_grad():
    #generating prediction & passing the prediction through torch.sigmoid 
    pred_mask = (torch.sigmoid(change_model(val_ds[s][0].unsqueeze(dim=0).to(device),val_ds[s][1].unsqueeze(dim=0).to(device))).squeeze()).detach().cpu().numpy()  


# displaying sample image1, sample image2, sample ground truth mask, and predicted mask    
fig,ax = plt.subplots(2,2,figsize=(10,10))
ax[0][0].imshow(val_ds[s][0].numpy().transpose(1,2,0))
ax[0][1].imshow(val_ds[s][1].numpy().transpose(1,2,0))
ax[1][0].imshow(val_ds[s][2].numpy().transpose())
ax[1][1].imshow(pred_mask)

# %%
PATH="/content/drive/MyDrive/TrainedModels/kaggle_change_detection_nb"
torch.save(change_model.state_dict(), PATH)

# %%
change_model.load_state_dict(torch.load(PATH))
change_model.eval()

# %%
change_model.eval()  #setting model to eval for generating predictions

s = 1 # sample - random

with torch.no_grad():
    #generating prediction & passing the prediction through torch.sigmoid 
    pred_mask = (torch.sigmoid(change_model(val_ds[s][0].unsqueeze(dim=0).to(device),val_ds[s][1].unsqueeze(dim=0).to(device))).squeeze()).detach().cpu().numpy()  


# displaying sample image1, sample image2, sample ground truth mask, and predicted mask    
fig,ax = plt.subplots(2,2,figsize=(10,10))
ax[0][0].imshow(val_ds[s][0].numpy().transpose(1,2,0))
ax[0][1].imshow(val_ds[s][1].numpy().transpose(1,2,0))
ax[1][0].imshow(val_ds[s][2].numpy().transpose())
ax[1][1].imshow(pred_mask)

# %%
#Process Ankara Verisi

# %%
# !pip install rasterio
# Out:
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 307 kB/s
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.21.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (21.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2021.10.8)
# Collecting affine
#   Downloading affine-2.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (3.0.7)
# Installing collected packages: snuggs, cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.3.0 click-plugins-1.1.1 cligj-0.7.2 rasterio-1.2.10 snuggs-1.4.7

# %%
## Creating 

import os
import rasterio

out_folder ="/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands"
input_tif ="/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/S2SR_20160929.tif"
#out_folder ="/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2020/All_Bands"
#input_tif ="/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2020/S2SR_20200928.tif"
src_raster = rasterio.open(input_tif)
for band in range(1, src_raster.count + 1):
        single_band = src_raster.read(band)

        # get the output name
        out_name = os.path.basename(input_tif)
        file, ext = os.path.splitext(out_name)
        name = file + "_" + "B" + str(band) + ".tif"
        out_img = os.path.join(out_folder, name)

        print(out_img + " done")

        # Copy the metadata
        out_meta = src_raster.meta.copy()

        out_meta.update({"count": 1})

        # save the clipped raster to disk
        with rasterio.open(out_img, "w", **out_meta) as dest:
               dest.write(single_band, 1)
# Out:
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B1.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B2.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B3.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B4.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B5.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B6.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B7.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B8.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B9.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B10.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B11.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B12.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B13.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B14.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B15.tif done
# /content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/All_Bands/S2SR_20160929_B16.tif done

# %%
# !pip install fiona
# Out:
# Collecting fiona
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 7.0 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona) (1.1.1)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona) (0.7.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona) (21.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona) (1.15.0)
# Installing collected packages: fiona
# Successfully installed fiona-1.8.21

# %%
# imports
from shapely.geometry import box, mapping
import fiona
import rasterio

raster =src_raster
output_fileName='/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2016/ankara.geojson'
#output_fileName='/content/drive/MyDrive/SentinelImages_Ankara_Clipped_2020/ankara.geojson'

# create a Polygon from the raster bounds
bbox = box(*raster.bounds)

# create a schema with no properties
schema = {'geometry': 'Polygon', 'properties': {}}

# create shapefile
#with fiona.open(output_fileName, 'w', driver='ESRI Shapefile',
#                crs=raster.crs.to_dict(), schema=schema) as c:
#    c.write({'geometry': mapping(bbox), 'properties': {}})


with fiona.open(output_fileName,'w',  driver ="GeoJSON", schema=schema, encoding = 'utf-8', crs=raster.crs.to_dict()) as geojson:
     geojson.write({'geometry': mapping(bbox), 'properties': {}})
